# %% [markdown]
# # Linear Regression

# %% [markdown]
# Let's fabricate some data that shows a roughly linear relationship between page speed and amount purchased:

# %%
# %matplotlib inline #function to display plots inline directly below the cell
import numpy as np # library used for scientfic computing in python
from pylab import * # module that combines functionalities from numpy and mathplot

pageSpeeds = np.random.normal(3.0, 1.0, 1000) #Generatesan array of 1000 random numbers from a normal distribution with a mean 3 and standard deviation 1.0
purchaseAmount = 100 - (pageSpeeds + np.random.normal(0, 0.1, 1000)) * 3 #

scatter(pageSpeeds, purchaseAmount)

# %% [markdown]
# As we only have two features, we can keep it simple and just use scipy.state.linregress:

# %%
from scipy import stats

slope, intercept, r_value, p_value, std_err = stats.linregress(pageSpeeds, purchaseAmount)

# %% [markdown]
# Not surprisngly, our R-squared value shows a really good fit:

# %%
r_value ** 2
# Out:
# 0.9907129750701099

# %% [markdown]
# Let's use the slope and intercept we got from the regression to plot predicted values vs. observed:

# %%
import matplotlib.pyplot as plt

def predict(x):
    return slope * x + intercept

fitLine = predict(pageSpeeds)

plt.scatter(pageSpeeds, purchaseAmount)
plt.plot(pageSpeeds, fitLine, c='r')
plt.show()

# %% [markdown]
# ## Activity

# %%
## answer:
# %matplotlib inline
import numpy as np
from pylab import*

pageSpeeds = np.random.normal(3.0, 1.0, 1000)
purchaseAmount = 100 - (pageSpeeds + np.random.normal(0, 0.5, 1000))

scatter(pageSpeeds, purchaseAmount)
show()

# %%
from scipy import stats

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(pageSpeeds, purchaseAmount)

# %%
r_squared = r_value ** 2
r_squared
# Out:
# 0.8097981446872395

# %%
import matplotlib.pyplot as plt

def predict(x):
    return slope * x + intercept

fitLine = predict(pageSpeeds)

plt.scatter(pageSpeeds, purchaseAmount)
plt.plot(pageSpeeds, fitLine, c='r')
plt.show()
